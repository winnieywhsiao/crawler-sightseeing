# %%
import pymysql
import time
import re
tStart = time.time()

#加入site資料到資料庫
def add_Data(n_id, site, name, near_site, near_href, near_comment, city_name, city_site, sid, postDay):
    add_data = ("INSERT INTO comment_relationship"
                "(id,site,name,near_site,near_href,near_comment,city_name,city_site,sid,postDay) "
                "VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)")
    data = (n_id, site, name, near_site, near_href, near_comment, city_name, city_site, sid, postDay)
    cur.execute(add_data, data)
    cnx.commit()

cnx = pymysql.connect(
    host="localhost",
    user="root",
    passwd="12345",
    database='test'
)

cm_cur = cnx.cursor() #
cr = cnx.cursor()
cur = cnx.cursor() #
ex = cnx.cursor()

cm_name = "SELECT * FROM hotel_relationship"
cm_cur.execute(cm_name)
for cm in cm_cur.fetchall():
    n_id=""
    site = cm[1]
    name = cm[2]
    near_site = cm[3]
    near_href = cm[4]
    near_comment = cm[5]
    city_name = cm[6]
    city_site = cm[7]
    sid = cm[8]
    postDay = cm[9]
    
    #print(site)
    
    # id, site, name, near_site, near_href, near_comment, city_name, city_site, sid, postDay
    add_Data(n_id, site, name, near_site,
             near_href, near_comment, city_name, city_site, sid, postDay)
    
    print(site)
tEnd = time.time()
print("Run Time：", tEnd - tStart)
# Out:
# 康橋大飯店
# 康橋大飯店
# 台東桂田喜來登酒店
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 台東桂田喜來登酒店
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 旅人驛站-鐵花文創館
# 凱旋星光酒店
# 台東桂田喜來登酒店
# 凱旋星光酒店
# 凱旋星光酒店
# 凱旋星光酒店
# 凱旋星光酒店
# 凱旋星光酒店
# 凱旋星光酒店
# 凱旋星光酒店
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 台東桂田喜來登酒店
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 台東桂田喜來登酒店
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 台東桂田喜來登酒店
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 幸福旅行舍
# 翠安儂風旅
# 台東桂田喜來登酒店
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 台東桂田喜來登酒店
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# 翠安儂風旅
# F HOTEL-知本館
# F HOTEL-知本館
# 台東桂田喜來登酒店
# F HOTEL-知本館
# F HOTEL-知本館
# F HOTEL-知本館
# F HOTEL-知本館
# F HOTEL-知本館
# F HOTEL-知本館
# F HOTEL-知本館
# F HOTEL-知本館
# ...

# %%
# restaurant_attr
import pymysql
import time

tStart = time.time()

cnx = pymysql.connect(
    host="localhost",
    user="root",
    passwd="123456",
    database='test'
    )

cursor = cnx.cursor()
cur = cnx.cursor()

category = []
co = []
sh = []
tag = "SELECT category FROM restaurant_data"
cursor.execute(tag)
count = 0

for row in cursor.fetchall():
    cate = row[0]
    
    if cate not in category:
        category.append(cate)
        co.append("red")
        sh.append("square")
        count += 1
    
    
# print(category)
# print(count)

def add_Data(r_id, tag, color, shape):
    add_data = ("INSERT INTO restaurant_attr"
                "(id,tag,color,shape) "
                "VALUES (%s,%s,%s,%s)")
    data = (r_id, tag, color, shape)
    cur.execute(add_data, data)
#     cnx.commit()

for p in range(len(category)):
    num  = ""
    tag = category[p]
    color = co[p]
    shape = sh[p]
    
    add_Data(num, tag, color, shape)

tEnd = time.time()
print("Run Time：", tEnd - tStart)

# %%
#renew restaurant id

import pymysql
import time

tStart = time.time()

cnx = pymysql.connect(
    host="localhost",
    user="root",
    passwd="123456",
    database='test'
    )

cursor = cnx.cursor()

new_id = []
n = []

last_id = ""
new = "SELECT id, href FROM restaurant_data"
cursor.execute(new)

for row in cursor:
    num = int(row[0])
    url = row[1]
    last_id = 'R{0:05}'.format(num)
    new_id.append(last_id)
    n.append(url)
    
cmr_cur = cnx.cursor()

for p in range(len(new_id)):
    cmr_sid = "UPDATE restaurant_data SET rid = '" + new_id[p] + "' WHERE href = '" + n[p] + "'"
    print(cmr_sid)
    
    cmr_cur.execute(cmr_sid)
    cnx.commit()

tEnd = time.time()
print("Run Time：", tEnd - tStart)

# %%
import pymysql
import time

tStart = time.time()

cnx = pymysql.connect(
    host="localhost",
    user="root",
    passwd="123456",
    database='test'
    )

cursor = cnx.cursor()
cur = cnx.cursor()

raid = []
rdcate = []
tag = "SELECT rd.id, rd.name, ra.id, rd.category FROM restaurant_data rd, restaurant_attr ra WHERE (rd.category = ra.tag)"
cursor.execute(tag)

for row in cursor.fetchall():
    from_id = row[0]
    to_id = row[2]
    
    raid.append(from_id)
    rdcate.append(to_id)
    
    
# print(raid)
# print(rdcate)

def add_Data(r_id,from_id,to_id):
    add_data = ("INSERT INTO restaurant_relationship"
                "(id,from_id,to_id) "
                "VALUES (%s,%s,%s)")
    data = (r_id,from_id,to_id)
    cur.execute(add_data, data)
    cnx.commit()

for p in range(len(raid)):
    num  = ""
    resid = raid[p]
    rescate = rdcate[p]
    
    add_Data(num,resid,rescate)

tEnd = time.time()
print("Run Time：", tEnd - tStart)
# Out:
# D:\Program Files\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect integer value: '' for column `test`.`restaurant_relationship`.`id` at row 1")
#   result = self._query(query)
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-102-9b2321d7e6c4> in <module>
#      43     rescate = rdcate[p]
#      44
# ---> 45     add_Data(num,resid,rescate)
#      46
#      47 tEnd = time.time()
#
# <ipython-input-102-9b2321d7e6c4> in add_Data(r_id, from_id, to_id)
#      35                 "VALUES (%s,%s,%s)")
#      36     data = (r_id,from_id,to_id)
# ---> 37     cur.execute(add_data, data)
#      38     cnx.commit()
#      39
#
# D:\Program Files\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
# ...

# %%
import pymysql
import time
import re
tStart = time.time()

#加入site資料到資料庫
def add_Data(r_id, tag, name, near_site, near_href, near_comment, city_name, city_site, sid, postDay):
    add_data = ("INSERT INTO comment_relationship"
                "(id,site,name,near_site,near_href,near_comment,city_name,city_site,sid,postDay) "
                "VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)")
    data = (n_id, site, name, near_site, near_href, near_comment, city_name, city_site, sid, postDay)
    cur.execute(add_data, data)
    cnx.commit()

cnx = pymysql.connect(
    host="localhost",
    user="root",
    passwd="123456",
    database='test'
)

cm_cur = cnx.cursor() #
cr = cnx.cursor()
cur = cnx.cursor() #
ex = cnx.cursor()

cm_name = "SELECT * FROM hotel_relationship"
cm_cur.execute(cm_name)
for cm in cm_cur.fetchall():
    n_id=""
    site = cm[1]
    name = cm[2]
    near_site = cm[3]
    near_href = cm[4]
    near_comment = cm[5]
    city_name = cm[6]
    city_site = cm[7]
    sid = cm[8]
    postDay = cm[9]
    
    #print(site)
    
    # id, site, name, near_site, near_href, near_comment, city_name, city_site, sid, postDay
    add_Data(n_id, site, name, near_site,
             near_href, near_comment, city_name, city_site, sid, postDay)
    
    print(site)
tEnd = time.time()
print("Run Time：", tEnd - tStart)
